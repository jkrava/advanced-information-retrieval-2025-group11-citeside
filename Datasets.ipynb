# %% [markdown]
# Huge Dataset S2ORC
#
# https://github.com/allenai/s2orc
# https://arxiv.org/pdf/1911.02782
#
# 81M+ paper nodes; 73M+ gold abstracts; 8M+ full text papers
# The combination of structured full text anno-
# tated with linked inline citations makes S2ORC
# well-suited for a variety of citation-related text-
# based tasks. Without any additional supervision,
# S2ORC can be used directly for both inline and document-level citation
# recommendation. Among document-level recom-
# menders, S2ORC is well-suited to the setting of
# Liu et al. (2015), who use inline citation contexts
# to filter document-level recommendations.
#
# GROBID is a machine learning library for extracting, parsing and re-structuring raw documents such as PDF into structured XML/TEI encoded documents with a particular focus on technical and scientific publications.
# https://github.com/kermitt2/grobid
#
# -> als mögliches preprocessing wie für application data??
#
#
# For our Usecase
#
# leminda-ai/s2orc_small
# https://huggingface.co/datasets/leminda-ai/s2orc_small
#
# A small split of the s2orc dataset, includes ~900k english papers with abstract included.

# %%
# !pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/28.0 MB 4.2 MB/s eta 0:00:07
#    - -------------------------------------- 1.0/28.0 MB 3.6 MB/s eta 0:00:08
#    -- ------------------------------------- 1.6/28.0 MB 3.2 MB/s eta 0:00:09
#    --- ------------------------------------ 2.4/28.0 MB 3.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.9/28.0 MB 3.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.7/28.0 MB 3.3 MB/s eta 0:00:08
#    ------ --------------------------------- 4.5/28.0 MB 3.3 MB/s eta 0:00:08
#    ------- -------------------------------- 5.0/28.0 MB 3.4 MB/s eta 0:00:07
#    ------- -------------------------------- 5.5/28.0 MB 3.3 MB/s eta 0:00:07
#    -------- ------------------------------- 6.3/28.0 MB 3.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 7.1/28.0 MB 3.3 MB/s eta 0:00:07
# ...

# %%
#https://huggingface.co/datasets/TabMaven/s2orc-academic-papers-augmented-v0
#sadly no citations in metadata

from datasets import load_dataset

ds = load_dataset("TabMaven/s2orc-academic-papers-augmented-v0")
ds["train"].column_names
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:121: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\datasets--TabMaven--s2orc-academic-papers-augmented-v0. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %% [markdown]
# Datenset über Corona Daten
#
# https://huggingface.co/datasets/allenai/cord19
#
# Currently only the following fields are integrated: ```cord_uid, sha,source_x, title, doi, abstract, publish_time, authors, journal```. With ```fulltext``` configuration, the sections transcribed in pdf_json_files are converted in fulltext feature.

# %% [markdown]
# Physics Scholarly Articles
#
# https://www.kaggle.com/datasets/shivd24coder/physics-scholarly-articles
#
# The dataset provides metadata such as publication year, authors, citations, and more. You can use this information to gain insights into the research landscape and the impact of specific papers.

# %% [markdown]
# Arxiv search
#
# https://searchthearxiv.com/

# %%
# !pip install requests
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# ...
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# ...
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests

url = "https://api.semanticscholar.org/graph/v1/paper/arXiv:1706.03762"
params = {"fields": "title,authors,year"}

response = requests.get(url, params=params)
print(response.json())
# Out:
# {'paperId': '204e3073870fae3d05bcbc2f6a8e263d9b72e776', 'title': 'Attention is All you Need', 'year': 2017, 'authors': [{'authorId': '40348417', 'name': 'Ashish Vaswani'}, {'authorId': '1846258', 'name': 'Noam Shazeer'}, {'authorId': '3877127', 'name': 'Niki Parmar'}, {'authorId': '39328010', 'name': 'Jakob Uszkoreit'}, {'authorId': '145024664', 'name': 'Llion Jones'}, {'authorId': '19177000', 'name': 'Aidan N. Gomez'}, {'authorId': '40527594', 'name': 'Lukasz Kaiser'}, {'authorId': '3443442', 'name': 'I. Polosukhin'}]}

# %% [markdown]
# Code from from https://github.com/allenai/s2orc?tab=readme-ov-file#download-instructions
#
# Download the Dataset.
# Plan: Use just a couple of shards from the dataset.
#
#
# ```
# import json
# import os
# import re
# import requests
# import wget
# from tqdm import tqdm
#
# # modify these
# API_KEY = "..."
# DATASET_NAME = "s2orc"
# LOCAL_PATH = "/my/local/path/for/s2orc/"
# os.makedirs(LOCAL_PATH, exist_ok=True)
#
# # get latest release's ID
# response = requests.get("https://api.semanticscholar.org/datasets/v1/release/latest").json()
# RELEASE_ID = response["release_id"]
# print(f"Latest release ID: {RELEASE_ID}")
#
# # get the download links for the s2orc dataset; needs to pass API key through `x-api-key` header
# # download via wget. this can take a while...
# response = requests.get(f"https://api.semanticscholar.org/datasets/v1/release/{RELEASE_ID}/dataset/{DATASET_NAME}/", headers={"x-api-key": API_KEY}).json()
# for url in tqdm(response["files"]):
#     match = re.match(r"https://ai2-s2ag.s3.amazonaws.com/staging/(.*)/s2orc/(.*).gz(.*)", url)
#     assert match.group(1) == RELEASE_ID
#     SHARD_ID = match.group(2)
#     wget.download(url, out=os.path.join(LOCAL_PATH, f"{SHARD_ID}.gz"))
# print("Downloaded all shards.")
# ```
